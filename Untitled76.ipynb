# %%
import pandas as pd
import plotly.express as px
import warnings

# Set style and palette
sns.set(style="whitegrid")
sns.set_palette("Blues_r")

energy_data = pd.read_excel("C:/Users/Sharon/Desktop/Data Analytics/Sustainable_Impact_Tracker.xlsx", sheet_name="Energy Consumption")
store_info = pd.read_excel("C:/Users/Sharon/Desktop/Data Analytics/Sustainable_Impact_Tracker.xlsx", sheet_name="Store Information")
waste_data = pd.read_excel("C:/Users/Sharon/Desktop/Data Analytics/Sustainable_Impact_Tracker.xlsx", sheet_name="Waste Management")
engagement_data = pd.read_excel("C:/Users/Sharon/Desktop/Data Analytics/Sustainable_Impact_Tracker.xlsx",  sheet_name="Employee Engagement")

warnings.simplefilter(action='ignore', category=FutureWarning)

# Set Bright palette
sns.set(style="whitegrid")
sns.set_palette("bright")

# 1. Energy Consumption by Store (Bar Chart)
plt.figure(figsize=(10, 6))
sns.barplot(data=energy_store_total, x='Energy_kWh', y='StoreName')
plt.title('Energy Consumption by Store (kWh)')
plt.xlabel('Energy (kWh)')
plt.ylabel('Store')
plt.tight_layout()
plt.show()

# 2. Waste Breakdown by Store and Type (Grouped Bar Chart)
plt.figure(figsize=(12, 6))
sns.barplot(data=waste_with_names, x='StoreName', y='Waste_kg', hue='WasteType')
plt.title('Waste Breakdown by Store and Type')
plt.xlabel('Store')
plt.ylabel('Waste (kg)')
plt.legend(title='Waste Type')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# 3. Total Energy Consumption by Region (Bar Chart)
plt.figure(figsize=(8, 5))
sns.barplot(data=region_energy, x='Energy_kWh', y='Region')
plt.title('Total Energy Consumption by Region')
plt.xlabel('Energy (kWh)')
plt.ylabel('Region')
plt.tight_layout()
plt.show()

# Calculate energy per square foot
energy_area = energy_data.groupby('StoreID')['Energy_kWh'].sum().reset_index()
energy_area = energy_area.merge(store_info[['StoreID', 'StoreName', 'Area_sqft']], on='StoreID')
energy_area['kWh_per_sqft'] = energy_area['Energy_kWh'] / energy_area['Area_sqft']
energy_area = energy_area.sort_values('kWh_per_sqft', ascending=False)

# 4. Plot energy efficiency by store
plt.figure(figsize=(10, 6))
sns.barplot(data=energy_area, x='kWh_per_sqft', y='StoreName')
plt.title('Energy Consumption per Square Foot by Store')
plt.xlabel('kWh per Square Foot')
plt.ylabel('Store')
plt.tight_layout()
plt.show()

## First, map StoreID to StoreName using a dictionary from store_info
store_id_to_name = dict(zip(store_info['StoreID'], store_info['StoreName']))
engagement_data['StoreName'] = engagement_data['StoreID'].map(store_id_to_name)

# Generate the boxplot 
plt.figure(figsize=(12, 6))
sns.boxplot(data=engagement_data, x='Initiative', y='ParticipationRate', palette="bright")
plt.title('Employee Participation Rate by Sustainability Initiative')
plt.xlabel('Initiative')
plt.ylabel('Participation Rate')
plt.xticks(rotation=20)
plt.tight_layout()
plt.show()


# Regenerate the map with Hobart removed but without mentioning it in the title
fig = px.scatter_geo(
    store_energy_map_filtered,
    lat='Latitude',
    lon='Longitude',
    text='StoreName',
    size='Energy_kWh',
    color='Region',
    projection='natural earth',
    title='Energy Consumption by Store (2024)',  # Clean title without mention of Hobart
    template='plotly_white'
)

fig.update_traces(marker=dict(line=dict(width=0.5, color='black')))
fig.update_layout(legend_title_text='Region')

# Zoom in on mainland Australia
fig.update_geos(
    visible=True,
    resolution=50,
    showcountries=True,
    lataxis_range=[-39, -10],
    lonaxis_range=[110, 155]
)

fig.show()
# Out:
# <div>                            <div id="b7cd5b05-44d2-42e1-b097-f80c2e9ea385" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7cd5b05-44d2-42e1-b097-f80c2e9ea385")) {                    Plotly.newPlot(                        "b7cd5b05-44d2-42e1-b097-f80c2e9ea385",                        [{"geo":"geo","hovertemplate":"Region=WA\u003cbr\u003eEnergy_kWh=%{marker.size}\u003cbr\u003eStoreName=%{text}\u003cbr\u003eLatitude=%{lat}\u003cbr\u003eLongitude=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","lat":[-31.9505],"legendgroup":"WA","lon":[115.8605],"marker":{"color":"#636efa","size":[175819],"sizemode":"area","sizeref":478.6425,"symbol":"circle","line":{"color":"black","width":0.5}},"mode":"markers+text","name":"WA","showlegend":true,"text":["North 
# ...
